# %% [markdown]
# <a href="https://colab.research.google.com/drive/1fDlJ6xeRmHfDsdqN5ATJ8lTj4lqavTqd?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <picture>
#     <source media="(prefers-color-scheme: dark)" srcset="https://raw.githubusercontent.com/simvue-io/.github/refs/heads/main/simvue-white.png" />
#     <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/simvue-io/.github/refs/heads/main/simvue-black.png" />
#     <img alt="Simvue" src="https://github.com/simvue-io/.github/blob/5eb8cfd2edd3269259eccd508029f269d993282f/simvue-black.png" width="500">
#   </picture>
# </p>
#
# # Example tracking a Non-Python Simulation
# This is an example of how you can build a Connector using our template to track and monitor a non-Python simulation or other computational task with Simvue. We will use a simple bash script to create some dummy 'temperature' data, looking at an experiment where the sample which is heated in an electric oven (causing its temperature to increase linearly), and then is taken out of the oven to cool down (losing temperature exponentially). We will then track this using the output file which is created during the experiment.
#
# Note that for some common simulation softwares, we already have custom made integrations packages which can be used. These include:
# * MOOSE (Multiphysics Object Oriented Simulation Environment)
# * OpenFOAM
# * FDS (Fire Dynamics Simulator)
# * TensorFlow

# %% [markdown]
# ### Install dependencies
# While you can use Simvue and Multiparser individually to achieve the tracking and monitoring of Non-Python files, we recommend using the `simvue-integrations-template` package which wraps these both together into a handy `WrappedRun` class. Install this if you have not done so already:

# %%
# %pip install simvue-connector
# Out:
# Requirement already satisfied: simvue-connector in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue-connector) (2.12.5)
# Requirement already satisfied: simvue>=2.4.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue-connector) (2.4.1)
# Requirement already satisfied: ukaea-multiparser>=1.0.2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue-connector) (1.0.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.5->simvue-connector) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.5->simvue-connector) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.5->simvue-connector) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.5->simvue-connector) (0.4.2)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (8.3.1)
# Requirement already satisfied: deepmerge<3.0,>=2.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.0)
# Requirement already satisfied: email-validator<3.0.0,>=2.2.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.3.0)
# Requirement already satisfied: flatdict==4.0.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (4.0.0)
# Requirement already satisfied: geocoder<2.0.0,>=1.38.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (1.38.1)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.44 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (3.1.46)
# Requirement already satisfied: humanfriendly<11.0,>=10.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (10.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (1.1.2)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.4.4)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.3.3)
# Requirement already satisfied: psutil<7.0.0,>=6.1.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (6.1.1)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.11.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.12.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (6.0.3)
# Requirement already satisfied: randomname<0.3.0,>=0.2.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (0.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (2.33.1)
# Requirement already satisfied: semver<4.0.0,>=3.0.4 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (3.0.4)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (0.9.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (9.1.4)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from simvue>=2.4.1->simvue-connector) (0.10.2)
# Requirement already satisfied: dnspython>=2.0.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from email-validator<3.0.0,>=2.2.0->simvue>=2.4.1->simvue-connector) (2.8.0)
# Requirement already satisfied: idna>=2.0.0 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from email-validator<3.0.0,>=2.2.0->simvue>=2.4.1->simvue-connector) (3.11)
# Requirement already satisfied: future in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from geocoder<2.0.0,>=1.38.1->simvue>=2.4.1->simvue-connector) (1.0.0)
# Requirement already satisfied: ratelim in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from geocoder<2.0.0,>=1.38.1->simvue>=2.4.1->simvue-connector) (0.1.6)
# Requirement already satisfied: six in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from geocoder<2.0.0,>=1.38.1->simvue>=2.4.1->simvue-connector) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.44->simvue>=2.4.1->simvue-connector) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.44->simvue>=2.4.1->simvue-connector) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.3->simvue>=2.4.1->simvue-connector) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.3->simvue>=2.4.1->simvue-connector) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.3->simvue>=2.4.1->simvue-connector) (2025.3)
# Requirement already satisfied: fire in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from randomname<0.3.0,>=0.2.1->simvue>=2.4.1->simvue-connector) (0.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->simvue>=2.4.1->simvue-connector) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->simvue>=2.4.1->simvue-connector) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->simvue>=2.4.1->simvue-connector) (2026.2.25)
# Requirement already satisfied: loguru>=0.7.3 in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from ukaea-multiparser>=1.0.2->simvue-connector) (0.7.3)
# Requirement already satisfied: termcolor in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from fire->randomname<0.3.0,>=0.2.1->simvue>=2.4.1->simvue-connector) (3.3.0)
# Requirement already satisfied: decorator in /home/wk9874/.cache/pypoetry/virtualenvs/simvue-connector-dumF_kxS-py3.12/lib/python3.12/site-packages (from ratelim->geocoder<2.0.0,>=1.38.1->simvue>=2.4.1->simvue-connector) (5.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Initialisation
# To proceed you need to specify the URL of the Simvue server and provide an access token used to authenticate to the server. This can be done by either creating a `simvue.toml` file containing the required details, or specifying them as environment variables.
#
# Login to https://uk.simvue.io, go to the **Runs** page and click **Create new run**. Copy the 'token' from here. The run the cell below, paste the token into the box when prompted and push enter.

# %%
import os
import getpass

os.environ["SIMVUE_URL"] = "https://uk.simvue.io"
os.environ["SIMVUE_TOKEN"] = getpass.getpass(prompt="Token: ")

# %% [markdown]
# ### Using the WrappedRun class
# To track our experiment, we will use the `add_process()` method to launch our bash script which generates the data, and we will use the `file_monitor` object to track our temperature data file. The WrappedRun class contains four methods which can be overridden to tailor to your needs:
# * `_pre_simulation`: Things to do before any output files are tracked, such as uploading artifacts or launching the simulation
# * `_during_simulation`: How to track the files created during the simulation and process data from them for upload to Simvue
# * `_post_simulation`: Things to do after the simulation is complete, such as uploading final results files
# * `launch`: Start the tracking session, calling each of the three methods above
#
# In our case, we want to:
# * Override `launch` to accept the path to the bash script
# * Override `_pre_simulation` to upload and run the bash script
# * Override `_during_simulation` to read from the temperature data as it is written and upload it as a metric
#
# Note that `WrappedRun` inherits from Simvue's `Run` class, so contains all of the methods you are already familiar with such as `log_metrics`, `log_events` etc...

# %%
from simvue_connector.connector import WrappedRun
import multiparser.parsing.tail as mp_tail_parser
import time
import pathlib

# Create a new class which inherits from WrappedRun
class TemperatureRun(WrappedRun):
    script_path: pathlib.Path = None
    
    # Override the `_pre_simulation` method to launch the process
    def _pre_simulation(self):
        # Call the base method first
        super()._pre_simulation()
        
        # Add a process to the run using `add_process`
        self.add_process(
            identifier="heating_experiment",
            executable="bash",
            script=self.script_path,
            completion_trigger=self._trigger # Sets a threading Event once the simulation is completed
        )
    
    # Override the `_during_simulation` method to track the temperature data
    def _during_simulation(self):
        # Use the `tail` method of the Multiparser `FileMonitor` object to track file, line by line
        self.file_monitor.tail(
            path_glob_exprs=str(self.script_path.with_suffix(".csv")),
            parser_func=mp_tail_parser.record_csv, # Use the built-in CSV parser, which returns a dictionary of data and metadata as each line is written
            callback=lambda csv_data, metadata: self.log_metrics( # Use data from those two dictionaries to log a metric:
                {'sample_temperature': csv_data["Temperature"]},
                 time=csv_data["Time"], 
                 step=csv_data["Step"], 
                 ) 
        )
    
    # Override the `launch` method to accept the path to the bash script
    def launch(self, script_path: str):
        self.script_path = script_path
        # Call the base `launch` method to call the above methods in the correct order
        super().launch()

# %% [markdown]
# ### Using our TemperatureRun class
# We can then use our `TemperatureRun` class in the same way as we would use the Simvue `Run` class - use it as a context manager, and call the `init` method. We can then add any additional information we want to store, before running the simulation by calling the `launch` method:

# %%
with TemperatureRun() as run:
    
    run.init(
        name="heating-cooling-example-%d" % time.time(),
        folder="/examples",
        description="Simulate an experiment where a sample is heated and then left to cool, tracking the temperature.",
        tags=["example", "heating-cooling"],
    )
    
    # Can upload extra things we care about, eg could upload some metadata
    run.update_metadata(
        {
            "initial_temperature": 20,
            "heating_time": 50,
            "cooling_time": 100
        }
    )
    # Then run launch to start the experiment
    run.launch(pathlib.Path.cwd().joinpath("temperatures.sh"))
    
    # Then once complete, can upload any other information before closing the run
    run.save_file(pathlib.Path.cwd().joinpath("temperatures.csv"), category="output")
# Out:
# [simvue] Run heating-cooling-example-1775125984 created
# [simvue] Monitor in the UI at https://uk.simvue.io/dashboard/runs/run/V3JGtazg9FyMjEqG4WdwER
# ℹ️ | 0:00:05.142908  | INFO     | multiparser | Found NEW log '/home/wk9874/Documents/simvue/connectors-generic/examples/temperatures.csv'

# %% [markdown]
# ### Results
# That's it! You can now view the run in the Simvue UI by clicking on the link above. You should be able to see:
# * A new run has been created in the `/examples` folder, with the name, tags and description which we specified in the `init` method
# * The run has a set of metadata detailing some of our inputs to the simulation
# * The simulation was automatically launched as a Simvue process
# * The bash script used was uploaded as a Code artifact
# * The temperature is being parsed from the CSV file and uploaded as a metric in real time
# * Once complete, the CSV results file is uploaded as an Output artifact
